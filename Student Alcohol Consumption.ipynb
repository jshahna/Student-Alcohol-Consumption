# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

# %%
#Load the CSV file into a DataFrame
student_math = pd.read_csv('student-mat.csv')
student_por = pd.read_csv('student-por.csv')

# %%
student_math.info()
student_math.describe()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 395 entries, 0 to 394
# Data columns (total 33 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   school      395 non-null    object
#  1   sex         395 non-null    object
#  2   age         395 non-null    int64
#  3   address     395 non-null    object
#  4   famsize     395 non-null    object
#  5   Pstatus     395 non-null    object
#  6   Medu        395 non-null    int64
#  7   Fedu        395 non-null    int64
#  8   Mjob        395 non-null    object
#  9   Fjob        395 non-null    object
#  10  reason      395 non-null    object
#  11  guardian    395 non-null    object
#  12  traveltime  395 non-null    int64
#  13  studytime   395 non-null    int64
#  14  failures    395 non-null    int64
#  15  schoolsup   395 non-null    object
#  16  famsup      395 non-null    object
#  17  paid        395 non-null    object
#  18  activities  395 non-null    object
# ...

# %%
student_por.info()
student_por.describe()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 649 entries, 0 to 648
# Data columns (total 33 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   school      649 non-null    object
#  1   sex         649 non-null    object
#  2   age         649 non-null    int64
#  3   address     649 non-null    object
#  4   famsize     649 non-null    object
#  5   Pstatus     649 non-null    object
#  6   Medu        649 non-null    int64
#  7   Fedu        649 non-null    int64
#  8   Mjob        649 non-null    object
#  9   Fjob        649 non-null    object
#  10  reason      649 non-null    object
#  11  guardian    649 non-null    object
#  12  traveltime  649 non-null    int64
#  13  studytime   649 non-null    int64
#  14  failures    649 non-null    int64
#  15  schoolsup   649 non-null    object
#  16  famsup      649 non-null    object
#  17  paid        649 non-null    object
#  18  activities  649 non-null    object
# ...

# %%
student_math.nunique()
student_por.nunique()
# Out:
# school         2
# sex            2
# age            8
# address        2
# famsize        2
# Pstatus        2
# Medu           5
# Fedu           5
# Mjob           5
# Fjob           5
# reason         4
# guardian       3
# traveltime     4
# studytime      4
# failures       4
# schoolsup      2
# famsup         2
# paid           2
# activities     2
# nursery        2
# higher         2
# internet       2
# romantic       2
# famrel         5
# freetime       5
# goout          5
# Dalc           5
# Walc           5
# health         5
# absences      24
# G1            17
# G2            16
# G3            17
# dtype: int64

# %%
numerical_cols = student_math.select_dtypes(include='number')
sns.heatmap(numerical_cols.corr().abs(), annot= True, fmt='.1f')
plt.show()

# %%
numerical_cols = student_por.select_dtypes(include='number')
sns.heatmap(numerical_cols.corr().abs(), annot= True, fmt = '.1f' )
plt.show()

# %%
student_math.duplicated().sum()
# student_por.duplicated().sum()
# Out:
# np.int64(0)

# %%
student_math.isnull().sum()
student_por.isnull().sum()
# Out:
# school        0
# sex           0
# age           0
# address       0
# famsize       0
# Pstatus       0
# Medu          0
# Fedu          0
# Mjob          0
# Fjob          0
# reason        0
# guardian      0
# traveltime    0
# studytime     0
# failures      0
# schoolsup     0
# famsup        0
# paid          0
# activities    0
# nursery       0
# higher        0
# internet      0
# romantic      0
# famrel        0
# freetime      0
# goout         0
# Dalc          0
# Walc          0
# health        0
# absences      0
# G1            0
# G2            0
# G3            0
# dtype: int64

# %%
productive = student_por[(student_por['studytime'] <=1) & (student_por['G3']>=16) ]
productive['schoolsup']
# Out:
# 15      no
# 61     yes
# 113     no
# 212     no
# 276     no
# 344     no
# 356     no
# 364     no
# 378     no
# 439     no
# 472     no
# 499     no
# 595     no
# Name: schoolsup, dtype: object

# %%
productive.describe()
# Out:
#              age       Medu       Fedu  traveltime  studytime   failures  \
# count  13.000000  13.000000  13.000000   13.000000       13.0  13.000000
# mean   16.461538   3.153846   2.923077    1.692308        1.0   0.076923
# std     0.967418   1.068188   1.187542    1.031553        0.0   0.277350
# min    15.000000   1.000000   1.000000    1.000000        1.0   0.000000
# 25%    16.000000   2.000000   2.000000    1.000000        1.0   0.000000
# 50%    16.000000   4.000000   3.000000    1.000000        1.0   0.000000
# 75%    17.000000   4.000000   4.000000    2.000000        1.0   0.000000
# max    18.000000   4.000000   4.000000    4.000000        1.0   1.000000
#
#           famrel   freetime      goout       Dalc       Walc     health  \
# count  13.000000  13.000000  13.000000  13.000000  13.000000  13.000000
# mean    3.923077   3.307692   3.692308   1.615385   2.076923   3.846154
# std     1.037749   1.182132   1.182132   1.192928   1.441153   1.405119
# ...

# %%
pd.set_option('display.max_columns', None)

# %%
counter = student_por[(student_por['studytime'] >=3) & (student_por['G3']<=9) ]
counter
# Out:
#     school sex  age address famsize Pstatus  Medu  Fedu      Mjob      Fjob  \
# 81      GP   M   15       U     GT3       T     2     3     other     other
# 219     GP   F   17       U     GT3       T     3     4   at_home  services
# 347     GP   F   17       R     GT3       T     4     4  services  services
# 453     MS   F   16       U     GT3       T     1     2     other  services
# 454     MS   F   16       U     GT3       T     1     2     other  services
# 488     MS   F   19       U     GT3       T     1     1   at_home  services
# 502     MS   M   17       R     LE3       T     2     2  services  services
# 523     MS   M   18       U     LE3       T     4     4   at_home    health
# 585     MS   F   17       R     LE3       A     3     1     other   at_home
#
#          reason guardian  traveltime  studytime  failures schoolsup famsup  \
# 81         home   mother           1          3         0       yes     no
# ...

# %%
student_filtered = student_por[(student_por['Pstatus']=='T')&(student_por['guardian']=='other')]
student_filtered
# Out:
#     school sex  age address famsize Pstatus  Medu  Fedu      Mjob      Fjob  \
# 41      GP   M   15       U     LE3       T     4     4   teacher     other
# 127     GP   F   19       U     GT3       T     0     1   at_home     other
# 165     GP   F   15       R     GT3       T     3     3  services  services
# 206     GP   M   17       U     GT3       T     1     2   at_home  services
# 224     GP   F   19       U     GT3       T     3     3     other     other
# 256     GP   M   18       U     GT3       T     2     2     other   at_home
# 275     GP   F   18       U     GT3       T     2     1     other     other
# 283     GP   M   16       U     GT3       T     3     3   at_home     other
# 299     GP   F   20       R     GT3       T     2     1     other     other
# 311     GP   F   19       U     GT3       T     3     3     other  services
# 324     GP   M   18       U     GT3       T     1     2   at_home     other
# ...

# %%
filtered_table = student_por[(student_por['studytime'] <=2)]
filtered_table['G3'].max()
# Out:
# np.int64(19)

# %%
filtered_table = student_math[student_math['G3']>=15]
filtered_table['studytime'].count()
# Out:
# np.int64(73)

# %%
student_math['studytime']
# Out:
# 0      2
# 1      2
# 2      2
# 3      3
# 4      2
#       ..
# 390    2
# 391    1
# 392    1
# 393    1
# 394    1
# Name: studytime, Length: 395, dtype: int64

# %%
alcohol_issue= student_por[((student_por['Dalc']>=5) | (student_por['Walc']>=5))]
alcohol_issue
# Out:
#     school sex  age address famsize Pstatus  Medu  Fedu      Mjob      Fjob  \
# 29      GP   M   16       U     GT3       T     4     4   teacher   teacher
# 61      GP   F   16       U     GT3       T     1     1  services  services
# 66      GP   M   15       U     GT3       A     4     4     other  services
# 89      GP   M   16       U     LE3       A     4     4   teacher    health
# 100     GP   M   16       U     GT3       T     4     4  services  services
# 108     GP   M   15       R     GT3       T     4     4     other     other
# 128     GP   M   16       R     GT3       T     4     4   teacher   teacher
# 142     GP   M   18       U     LE3       T     3     1  services  services
# 143     GP   F   18       U     GT3       A     3     2     other  services
# 162     GP   M   15       U     LE3       A     2     1  services     other
# 163     GP   M   18       U     LE3       T     1     1     other     other
# ...

# %%
time_management= student_por[((student_por['freetime']==5) | (student_por['studytime']==4))]
time_management.describe()
# Out:
#              age       Medu       Fedu  traveltime  studytime   failures  \
# count  99.000000  99.000000  99.000000   99.000000  99.000000  99.000000
# mean   16.535354   2.595960   2.212121    1.696970   2.363636   0.262626
# std     1.231501   1.096555   1.002779    0.838543   1.305049   0.693790
# min    15.000000   1.000000   0.000000    1.000000   1.000000   0.000000
# 25%    15.000000   2.000000   1.000000    1.000000   1.000000   0.000000
# 50%    17.000000   3.000000   2.000000    2.000000   2.000000   0.000000
# 75%    17.000000   4.000000   3.000000    2.000000   4.000000   0.000000
# max    20.000000   4.000000   4.000000    4.000000   4.000000   3.000000
#
#           famrel   freetime      goout       Dalc       Walc     health  \
# count  99.000000  99.000000  99.000000  99.000000  99.000000  99.000000
# mean    3.888889   4.282828   3.585859   1.666667   2.343434   3.404040
# std     1.105542   1.178380   1.414286   1.178030   1.471925   1.524756
# ...

# %%
student_por['deltaG2']=student_por['G2']-student_por['G1']
student_por['deltaG3']=student_por['G3']-student_por['G2']
student_por.describe()
# Out:
#               age        Medu        Fedu  traveltime   studytime    failures  \
# count  649.000000  649.000000  649.000000  649.000000  649.000000  649.000000
# mean    16.744222    2.514638    2.306626    1.568567    1.930663    0.221880
# std      1.218138    1.134552    1.099931    0.748660    0.829510    0.593235
# min     15.000000    0.000000    0.000000    1.000000    1.000000    0.000000
# 25%     16.000000    2.000000    1.000000    1.000000    1.000000    0.000000
# 50%     17.000000    2.000000    2.000000    1.000000    2.000000    0.000000
# 75%     18.000000    4.000000    3.000000    2.000000    2.000000    0.000000
# max     22.000000    4.000000    4.000000    4.000000    4.000000    3.000000
#
#            famrel    freetime       goout        Dalc        Walc      health  \
# count  649.000000  649.000000  649.000000  649.000000  649.000000  649.000000
# mean     3.930663    3.180277    3.184900    1.502311    2.280431    3.536210
# ...

# %%
improvement= student_por[((student_por['deltaG2']>=5) | (student_por['deltaG3']>=5))]
improvement
# Out:
#     school sex  age address famsize Pstatus  Medu  Fedu      Mjob      Fjob  \
# 0       GP   F   18       U     GT3       A     4     4   at_home   teacher
# 61      GP   F   16       U     GT3       T     1     1  services  services
# 558     MS   M   17       R     GT3       T     2     2     other     other
# 568     MS   M   19       U     GT3       T     3     2   at_home  services
#
#      reason guardian  traveltime  studytime  failures schoolsup famsup paid  \
# 0    course   mother           2          2         0       yes     no   no
# 61   course   father           4          1         0       yes    yes   no
# 558  course   mother           2          1         0        no     no   no
# 568  course   mother           2          1         3        no     no   no
#
#     activities nursery higher internet romantic  famrel  freetime  goout  \
# 0           no     yes    yes       no       no       4         3      4
# ...

# %%
Regression= student_por[((student_por['deltaG2']<=-5) | (student_por['deltaG3']<=-5))]
Regression
# Out:
#     school sex  age address famsize Pstatus  Medu  Fedu     Mjob      Fjob  \
# 163     GP   M   18       U     LE3       T     1     1    other     other
# 172     GP   M   16       U     GT3       T     3     3    other  services
# 440     MS   M   16       U     GT3       T     1     1  at_home  services
# 519     MS   M   16       R     GT3       T     2     1    other  services
# 563     MS   M   17       U     GT3       T     2     2    other     other
# 583     MS   F   18       R     GT3       T     2     2    other     other
# 586     MS   F   17       U     GT3       T     4     2  teacher  services
# 597     MS   F   18       R     GT3       T     2     2  at_home     other
# 603     MS   F   18       R     LE3       A     4     2  teacher     other
# 605     MS   F   19       U     GT3       T     1     1  at_home  services
# 610     MS   F   19       R     GT3       A     1     1  at_home   at_home
# ...
